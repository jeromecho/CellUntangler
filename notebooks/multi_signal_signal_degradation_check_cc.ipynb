# %% [markdown]
# ### GOAL
# Notebook aims to disentangle HGSOC RNA data into 2+ data spaces (Cell Cycle Signal Space, Inteferon Signal Space, Cell Dissociation Signal Space, Cell Type Signal Space)

# %%
import sys
import os

# Get the directory containing the notebook
NOTEBOOK_DIR = os.getcwd()

# Compute project root (go up one level)
PROJECT_ROOT = os.path.abspath(os.path.join(NOTEBOOK_DIR, '..'))

# Add project root to path
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

# %%
import scanpy as sc
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
from src.data.umi_data import UMIVaeDataset
from src.celluntangler import utils
from src.celluntangler.models import Trainer
from src.celluntangler.models.nb_vae import NBVAE
from src.visualization.helpers import split_embeddings
from src.visualization.visualization_functions import visualize_poincare_from_lorentz, visualize_embedding, visualize_2d

# %%
from src.paths.paths import ALL_CELLS_PATH

# %%
# TODO - change path to actual data you care about
# TODO - debug getting HVG genes working with annotated dataframe
adata = sc.read_h5ad("../../../data/HGSOC/ALL_CELLS/all_cells_1p_hvg2000.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 10199 × 2000
#     obs: 'percent.mt', 'percent.rb', 'doublet', 'author_sample_id', 'S.Score', 'G2M.Score', 'Phase', 'CC.Diff', 'author_cell_type', 'nCount_RNA', 'nFeature_RNA', 'doublet_score', 'cell_type_ontology_term_id', 'tissue_ontology_term_id', 'assay_ontology_term_id', 'suspension_type', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'sex_ontology_term_id', 'donor_id', 'author_tumor_supersite', 'author_tumor_site', 'author_tumor_subsite', 'author_sort_parameters', 'author_therapy', 'author_procedure', 'author_procedure_type', 'is_primary_data', 'tissue_type', 'cell_type', 'assay', 'disease', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid'
#     var: 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'feature_type', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'author_cell_type_colors', 'citation', 'default_embedding', 'hvg', 'log1p', 'neighbors', 'organism', 'organism_ontology_term_id', 'schema_reference', 'schema_version', 'title'
#     obsm: 'X_pca', 'X_umap50'

# %% [markdown]
# ### Pre-processing

# %%
adata.var["gene_symbols"] = adata.var["feature_name"]

# %%
cell_cycle_genes_path = "../../../genes/celluntangler_human_cell_cycle_genes.tsv"

cell_cycle_genes = pd.read_csv(cell_cycle_genes_path, header = None, sep="\t")

# %%
## Brief Analysis of Number of Relevant Genes Found

# %%
cell_cycle_genes_set = set(cell_cycle_genes.iloc[:,0])

# %%
contained_genes_cc = adata.var["gene_symbols"].isin(cell_cycle_genes[0])

# %%
print(f"Number of cell cycle genes present in adata: {np.sum(contained_genes_cc)}")
# Out:
# Number of cell cycle genes present in adata: 16

# %%
# Order Genes in adata such that genes appear in following order: cell cycle genes, interferon genes, dissociation genes
cc_indices = np.where(contained_genes_cc)[0]

all_known_indices = np.hstack((cc_indices))
remaining_indices = np.setdiff1d(np.arange(adata.shape[1]), all_known_indices)

rearranged_indices = np.hstack((cc_indices, remaining_indices))
rearranged_indices = rearranged_indices.astype(int)

# %%
adata = adata[:, rearranged_indices] # .copy() is safer in AnnData
adata.uns["new_gene_ordering"] = rearranged_indices # NB: this takes a while to run!
# Out:
# /var/folders/2z/f9h5sjqj6m9dz0ljc7yy_plw0000gn/T/ipykernel_38781/1082852305.py:2: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns["new_gene_ordering"] = rearranged_indices # NB: this takes a while to run!

# %% [markdown]
# ### Model Configuration

# %%
model_name = "r2, e10"

# %%
from src.celluntangler.models.get_config import get_config
config = get_config()
config.model_name = model_name
config.seed = 68715
config.init = "custom"
config.max_epochs = 500 
config.epochs = 500

# %%
if config.seed:  
    torch.manual_seed(config.seed)
    np.random.seed(config.seed) 
    np.random.default_rng(config.seed)
components = utils.parse_components(model_name, config.fixed_curvature)

# %% [markdown]
# ### Creating Training Dataset

# %%
if not "batch" in adata.obs.columns.tolist(): 
    adata.obs["batch"] = adata.obs.index.str.split("_").str[0]
    adata.obs["batch"] = adata.obs["batch"].astype("category")

# %%
batch = adata.obs.batch.cat.codes.values 
batch = batch[:,None]
batch = batch.astype(np.int64)

# %%
# One entry in n_batch for each "factor of batch effects"
config.n_batch = [ len(np.unique(batch)) ]

# %%
batch_counts = np.bincount(batch[:,0])
batch_counts = batch_counts[1:]

# %%
# Creating Training Dataset
x = adata.X.todense().astype(np.double)

# %%
# y holds the batch vector for the dataset
y = batch 
in_dim = x.shape[1]
print(f"in_dim = {in_dim}")
batch_size = config.batch_size
dataset = UMIVaeDataset(batch_size=batch_size, in_dim=in_dim)
print(f"dataset.in_dim = {dataset.in_dim}")
# Create the dataset loaders
train_loader = dataset.create_loaders(x, y, seed=config.seed)
# Out:
# in_dim = 2000
# dataset.in_dim = 2000
# Dataset seed: 68715

# %%
# Creating (Disjoint) Masks
mask_cyc = np.zeros(adata.n_vars)

mask_all = np.ones(adata.n_vars)
mask_all[adata.var["gene_symbols"].isin(cell_cycle_genes[0])] = 0 
mask = torch.tensor([mask_cyc, mask_all])
# Out:
# /var/folders/2z/f9h5sjqj6m9dz0ljc7yy_plw0000gn/T/ipykernel_38781/1447850958.py:6: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:256.)
#   mask = torch.tensor([mask_cyc, mask_all])

# %% [markdown]
# ### Configure Save Paths

# %%
epoch_embeddings_save_path = "../../../results/multi_subspace/all_cells/01_13_signal_degradation_check_cc"

# %%
visualize_information={}
# The epochs to save the intermediate embeddings for
visualize_information["epochs"]=[i for i in range(0, 500, 50)] 
visualize_information["x"]=x
visualize_information["y"]=y
visualize_information["embeddings_save_path"]=epoch_embeddings_save_path
visualize_information["model_name"]=config.model_name
visualize_information["device"]=config.device

# %% [markdown]
# ### Model Creation

# %%
use_gpu = False
if use_gpu:
  print("Using GPU")
  config.device = torch.device("cuda")
else:
  print("Using CPU")
  config.device = torch.device("cpu")
# Out:
# Using CPU

# %%
torch.set_default_dtype(torch.float64)

# %%
model = NBVAE(h_dim=config.h_dim,
              components=components,
              mask=mask,
              dataset=dataset,
              config=config).to(config.device)
# Out:
# Linear(in_features=32, out_features=2, bias=True)
# initializing Xavier uniform weights in Linear
# Linear(in_features=32, out_features=2, bias=True)
# initializing Xavier uniform weights in Linear
# RotatedHyperbolicComponent(R^3)

# %% [markdown]
# ### Training

# %%
trainer = Trainer(model)

optimizer = trainer.build_optimizer(learning_rate=config.learning_rate,
                                        fixed_curvature=config.fixed_curvature,
                                        use_adamw=config.use_adamw,
                                        weight_decay=config.weight_decay)

betas = utils.linear_betas(config.start,
                           config.end,
                           end_epoch=config.end_epoch,
                           epochs=config.epochs)


trainer.train_epochs(optimizer=optimizer,
                       train_data=train_loader,
                       betas=betas,
                       likelihood_n=0,
                       max_epochs=config.max_epochs,
                       visualize_information=visualize_information)
# Out:
# initialized early stopper
# 	TrainEpoch 0:
# /Users/jeromecho/Library/CloudStorage/OneDrive-Personal/Thesis/thesis/code/venvs/CellUntangler/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# {'bce': -777.942, 'kl': 20.575, 'elbo': -798.517, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 1:	{'bce': -556.13, 'kl': 6.899, 'elbo': -563.029, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 2:	{'bce': -544.881, 'kl': 5.461, 'elbo': -550.342, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 3:	{'bce': -536.96, 'kl': 5.183, 'elbo': -542.143, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 4:	{'bce': -529.286, 'kl': 5.155, 'elbo': -534.442, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 5:	{'bce': -521.558, 'kl': 5.105, 'elbo': -526.662, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 6:	{'bce': -515.21, 'kl': 4.935, 'elbo': -520.145, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 7:	{'bce': -506.029, 'kl': 5.588, 'elbo': -511.617, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 8:	{'bce': -482.613, 'kl': 7.877, 'elbo': -490.489, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 9:	{'bce': -463.87, 'kl': 8.661, 'elbo': -472.531, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 10:	{'bce': -455.411, 'kl': 8.344, 'elbo': -463.755, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 11:	{'bce': -451.193, 'kl': 7.964, 'elbo': -459.156, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 12:	{'bce': -447.424, 'kl': 7.783, 'elbo': -455.208, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 13:	{'bce': -444.43, 'kl': 7.527, 'elbo': -451.957, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 14:	{'bce': -441.872, 'kl': 7.35, 'elbo': -449.222, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 15:	{'bce': -439.883, 'kl': 7.148, 'elbo': -447.03, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 16:	{'bce': -438.167, 'kl': 6.814, 'elbo': -444.981, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 17:	{'bce': -436.465, 'kl': 6.53, 'elbo': -442.995, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 18:	{'bce': -434.761, 'kl': 6.41, 'elbo': -441.171, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 19:	{'bce': -433.014, 'kl': 6.275, 'elbo': -439.29, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 20:	{'bce': -431.536, 'kl': 6.219, 'elbo': -437.755, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 21:	{'bce': -430.167, 'kl': 6.283, 'elbo': -436.45, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 22:	{'bce': -428.832, 'kl': 6.114, 'elbo': -434.946, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 23:	{'bce': -427.666, 'kl': 6.011, 'elbo': -433.676, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 24:	{'bce': -426.959, 'kl': 6.006, 'elbo': -432.966, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 25:	{'bce': -425.887, 'kl': 5.987, 'elbo': -431.874, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 26:	{'bce': -424.682, 'kl': 5.963, 'elbo': -430.645, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 27:	{'bce': -423.85, 'kl': 5.933, 'elbo': -429.783, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 28:	{'bce': -422.9, 'kl': 5.944, 'elbo': -428.844, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 29:	{'bce': -422.171, 'kl': 5.96, 'elbo': -428.131, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 30:	{'bce': -421.241, 'kl': 5.973, 'elbo': -427.214, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 31:	{'bce': -420.236, 'kl': 6.057, 'elbo': -426.293, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 32:	{'bce': -418.971, 'kl': 6.156, 'elbo': -425.127, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 33:	{'bce': -417.51, 'kl': 6.366, 'elbo': -423.875, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 34:	{'bce': -416.463, 'kl': 6.46, 'elbo': -422.924, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 35:	{'bce': -415.324, 'kl': 6.558, 'elbo': -421.882, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 36:	{'bce': -414.274, 'kl': 6.61, 'elbo': -420.885, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 37:	{'bce': -413.502, 'kl': 6.637, 'elbo': -420.14, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 38:	{'bce': -412.689, 'kl': 6.679, 'elbo': -419.368, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 39:	{'bce': -411.705, 'kl': 6.723, 'elbo': -418.428, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 40:	{'bce': -411.172, 'kl': 6.792, 'elbo': -417.964, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 41:	{'bce': -410.189, 'kl': 6.805, 'elbo': -416.994, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 42:	{'bce': -409.275, 'kl': 6.882, 'elbo': -416.156, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 43:	{'bce': -408.536, 'kl': 6.908, 'elbo': -415.444, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 44:	{'bce': -407.847, 'kl': 6.959, 'elbo': -414.807, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 45:	{'bce': -407.03, 'kl': 7.004, 'elbo': -414.034, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 46:	{'bce': -406.412, 'kl': 7.017, 'elbo': -413.429, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 47:	{'bce': -405.838, 'kl': 7.052, 'elbo': -412.89, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 48:	{'bce': -404.926, 'kl': 7.081, 'elbo': -412.007, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 49:	{'bce': -404.424, 'kl': 7.14, 'elbo': -411.564, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 50:	{'bce': -403.684, 'kl': 7.141, 'elbo': -410.825, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 51:	{'bce': -403.055, 'kl': 7.173, 'elbo': -410.228, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 52:	{'bce': -402.761, 'kl': 7.226, 'elbo': -409.987, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 53:	{'bce': -402.047, 'kl': 7.32, 'elbo': -409.367, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 54:	{'bce': -401.413, 'kl': 7.29, 'elbo': -408.703, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 55:	{'bce': -400.807, 'kl': 7.301, 'elbo': -408.108, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 56:	{'bce': -400.263, 'kl': 7.282, 'elbo': -407.545, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 57:	{'bce': -399.811, 'kl': 7.307, 'elbo': -407.119, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 58:	{'bce': -399.439, 'kl': 7.376, 'elbo': -406.815, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 59:	{'bce': -398.959, 'kl': 7.334, 'elbo': -406.293, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 60:	{'bce': -398.708, 'kl': 7.368, 'elbo': -406.076, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 61:	{'bce': -398.101, 'kl': 7.333, 'elbo': -405.435, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 62:	{'bce': -397.833, 'kl': 7.382, 'elbo': -405.216, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 63:	{'bce': -397.29, 'kl': 7.395, 'elbo': -404.685, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 64:	{'bce': -396.984, 'kl': 7.404, 'elbo': -404.388, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 65:	{'bce': -396.366, 'kl': 7.432, 'elbo': -403.799, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 66:	{'bce': -396.01, 'kl': 7.454, 'elbo': -403.464, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 67:	{'bce': -395.747, 'kl': 7.438, 'elbo': -403.185, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 68:	{'bce': -395.4, 'kl': 7.465, 'elbo': -402.865, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 69:	{'bce': -395.149, 'kl': 7.443, 'elbo': -402.592, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 70:	{'bce': -395.048, 'kl': 7.476, 'elbo': -402.525, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 71:	{'bce': -395.001, 'kl': 7.469, 'elbo': -402.47, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 72:	{'bce': -394.304, 'kl': 7.525, 'elbo': -401.83, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 73:	{'bce': -393.933, 'kl': 7.517, 'elbo': -401.45, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 74:	{'bce': -393.652, 'kl': 7.556, 'elbo': -401.209, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 75:	{'bce': -393.614, 'kl': 7.589, 'elbo': -401.204, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 76:	{'bce': -393.025, 'kl': 7.643, 'elbo': -400.668, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 77:	{'bce': -392.694, 'kl': 7.597, 'elbo': -400.291, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 78:	{'bce': -392.385, 'kl': 7.57, 'elbo': -399.956, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 79:	{'bce': -392.14, 'kl': 7.571, 'elbo': -399.711, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 80:	{'bce': -392.032, 'kl': 7.589, 'elbo': -399.621, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 81:	{'bce': -391.765, 'kl': 7.576, 'elbo': -399.34, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 82:	{'bce': -391.522, 'kl': 7.55, 'elbo': -399.072, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 83:	{'bce': -391.239, 'kl': 7.578, 'elbo': -398.817, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 84:	{'bce': -391.298, 'kl': 7.569, 'elbo': -398.867, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 85:	{'bce': -390.912, 'kl': 7.579, 'elbo': -398.492, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 86:	{'bce': -390.658, 'kl': 7.56, 'elbo': -398.218, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 87:	{'bce': -390.349, 'kl': 7.57, 'elbo': -397.919, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 88:	{'bce': -390.079, 'kl': 7.613, 'elbo': -397.692, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 89:	{'bce': -389.932, 'kl': 7.611, 'elbo': -397.543, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 90:	{'bce': -389.836, 'kl': 7.596, 'elbo': -397.432, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 91:	{'bce': -389.532, 'kl': 7.584, 'elbo': -397.117, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 92:	{'bce': -389.483, 'kl': 7.571, 'elbo': -397.054, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 93:	{'bce': -389.213, 'kl': 7.622, 'elbo': -396.835, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 94:	{'bce': -389.044, 'kl': 7.654, 'elbo': -396.698, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 95:	{'bce': -388.776, 'kl': 7.652, 'elbo': -396.429, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 96:	{'bce': -388.69, 'kl': 7.64, 'elbo': -396.33, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 97:	{'bce': -388.528, 'kl': 7.639, 'elbo': -396.167, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 98:	{'bce': -388.389, 'kl': 7.635, 'elbo': -396.024, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 99:	{'bce': -388.255, 'kl': 7.646, 'elbo': -395.901, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 100:	{'bce': -388.112, 'kl': 7.644, 'elbo': -395.756, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 101:	{'bce': -388.391, 'kl': 7.748, 'elbo': -396.139, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 102:	{'bce': -387.785, 'kl': 7.739, 'elbo': -395.524, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 103:	{'bce': -387.574, 'kl': 7.664, 'elbo': -395.238, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 104:	{'bce': -387.407, 'kl': 7.673, 'elbo': -395.08, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 105:	{'bce': -387.28, 'kl': 7.711, 'elbo': -394.991, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 106:	{'bce': -387.275, 'kl': 7.674, 'elbo': -394.948, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 107:	{'bce': -387.018, 'kl': 7.668, 'elbo': -394.686, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 108:	{'bce': -386.8, 'kl': 7.701, 'elbo': -394.501, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 109:	{'bce': -386.652, 'kl': 7.691, 'elbo': -394.343, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 110:	{'bce': -386.513, 'kl': 7.708, 'elbo': -394.221, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 111:	{'bce': -386.394, 'kl': 7.699, 'elbo': -394.093, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 112:	{'bce': -386.383, 'kl': 7.713, 'elbo': -394.097, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 113:	{'bce': -386.223, 'kl': 7.703, 'elbo': -393.926, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 114:	{'bce': -386.067, 'kl': 7.746, 'elbo': -393.813, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 115:	{'bce': -386.002, 'kl': 7.738, 'elbo': -393.739, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 116:	{'bce': -385.756, 'kl': 7.737, 'elbo': -393.493, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 117:	{'bce': -385.718, 'kl': 7.735, 'elbo': -393.453, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 118:	{'bce': -385.701, 'kl': 7.731, 'elbo': -393.432, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 119:	{'bce': -385.412, 'kl': 7.723, 'elbo': -393.135, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 120:	{'bce': -385.364, 'kl': 7.739, 'elbo': -393.103, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 121:	{'bce': -385.208, 'kl': 7.722, 'elbo': -392.93, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 122:	{'bce': -385.043, 'kl': 7.707, 'elbo': -392.75, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 123:	{'bce': -384.95, 'kl': 7.74, 'elbo': -392.69, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 124:	{'bce': -384.84, 'kl': 7.764, 'elbo': -392.604, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 125:	{'bce': -384.813, 'kl': 7.737, 'elbo': -392.55, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 126:	{'bce': -384.663, 'kl': 7.738, 'elbo': -392.401, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 127:	{'bce': -384.744, 'kl': 7.79, 'elbo': -392.534, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 128:	{'bce': -384.609, 'kl': 7.809, 'elbo': -392.418, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 129:	{'bce': -384.397, 'kl': 7.787, 'elbo': -392.184, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 130:	{'bce': -384.272, 'kl': 7.78, 'elbo': -392.052, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 131:	{'bce': -384.402, 'kl': 7.776, 'elbo': -392.179, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 132:	{'bce': -384.222, 'kl': 7.818, 'elbo': -392.04, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 133:	{'bce': -384.061, 'kl': 7.766, 'elbo': -391.827, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 134:	{'bce': -383.985, 'kl': 7.769, 'elbo': -391.755, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 135:	{'bce': -383.938, 'kl': 7.811, 'elbo': -391.749, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# 	TrainEpoch 136:	{'bce': -383.889, 'kl': 7.807, 'elbo': -391.696, 'll': 0.0, 'mi': 0.0, 'cov_norm': 0.0, 'beta': 1.0, 'comp_000_r2/curvature': -2.0, 'comp_001_e10/curvature': 0.0}
# Early stopping at epoch 136. Best ELBO -392.4011 at epoch 126.

# %% [markdown]
# ### Saving Embeddings

# %%
embeddings_save_path = epoch_embeddings_save_path

# %%
checkpoint = torch.load(
    os.path.join(embeddings_save_path,  f"{model_name}_best_model.pt"),
    map_location=config.device
)
model.load_state_dict(checkpoint["model_state"])
model.eval()

# %%
a = trainer.model(torch.log1p(torch.tensor(x, device=config.device)), torch.tensor(y, device=config.device))
np.savetxt(os.path.join(embeddings_save_path, f'{model_name}_all_encode_v63_z_params.txt'), a[4].detach().to(torch.device("cpu")).numpy())

# %% [markdown]
# ### Analysis

# %%
gene_expression_matrix_path = epoch_embeddings_save_path

# %%
embeddings = np.loadtxt(os.path.join(embeddings_save_path, f'{model_name}_all_encode_v63_z_params_best.txt'))
component_embeddings = split_embeddings(model_name, embeddings)
for c in component_embeddings:
    adata.obsm[c] = component_embeddings[c]
# Out:
# r2 3
# e10 10

# %% [markdown]
# #### Visualization of Component 1 (R2)

# %% [markdown]
# ##### Visualization fo Cell Cycle Signals

# %%
embeddings_key = "component1_r2"
desired_obs = 'S.Score'
desired_obs_all = adata.obs[desired_obs]
legend_coordinates = (1.23,1.01)
fig = visualize_poincare_from_lorentz(adata.obsm[embeddings_key],
                       desired_obs_all,
                       curvature=-2,
                      embedding_type='continuous',
                       cmap=plt.cm.viridis,
                       cat_colors=None,
                      grid_lines=True,
                      c_bar_label="S.Score",
                      bbox_to_anchor=legend_coordinates)
# Out:
# /Users/jeromecho/Library/CloudStorage/OneDrive-Personal/Thesis/thesis/code/CellUntangler/src/visualization/visualization_functions.py:253: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc='upper right', bbox_to_anchor=bbox_to_anchor)

# %%
ax = adata.obs["S.Score"].hist()
ax.set_title("S Score Distribution")
# Out:
# Text(0.5, 1.0, 'S Score Distribution')

# %%
embeddings_key = "component1_r2"
desired_obs = 'G2M.Score'
desired_obs_all = adata.obs[desired_obs]
legend_coordinates = (1.23,1.01)
fig = visualize_poincare_from_lorentz(adata.obsm[embeddings_key],
                       desired_obs_all,
                       curvature=-2,
                      embedding_type='continuous',
                       cmap=plt.cm.viridis,
                       cat_colors=None,
                      grid_lines=True,
                      c_bar_label="G2N.Score",
                      bbox_to_anchor=legend_coordinates)

# %% [markdown]
# ##### Visualization of Non-Cell-Cycle Signals

# %%
# TODO - add custom UMAP code that doesn't hang! 
# Visualize UMAP using cell cycle ground truth, cell type ground truth, other labels, .... 
# TODO - add custom UMAP code that doesn't hang! 
# For preliminary analysis - just measure enrichment in some marker gene of cell dissociation response
# For preliminary analysis - just measure enrichment in some marker gene of interferon response
embeddings_key = "component2_e10"
desired_obs = 'G2M.Score'

visualize_embedding(
    embedding=adata.obsm[embeddings_key],
    obs_values=adata.obs[desired_obs],
    cmap=plt.cm.viridis,
    c_bar_label="Transcriptional Phase",
)

# %%
# Define consistent coloring for cell_types

import pandas as pd

cell_types = pd.Categorical(adata.obs["cell_type"])
categories = cell_types.categories

# Use tab20
base_cmap = plt.get_cmap("tab20")

# Ensure one-to-one mapping, repeat if >20
cat_colors = {}
for i, cat in enumerate(categories):
    cat_colors[cat] = base_cmap(i % 20)

# %%
embeddings_key = "component2_e10"
desired_obs = 'cell_type'

visualize_embedding(
    embedding=adata.obsm[embeddings_key],
    obs_values=adata.obs[desired_obs],
    cat_colors=cat_colors,   # <--- pass the fixed mapping
    point_size=8,
    alpha=0.9,
    figsize=(7,7),
    show_legend=False
)

# %%
adata.obsm[embeddings_key]
# Out:
# array([[-0.15051945,  1.52000961, -0.52237633, ...,  0.42655587,
#          0.51343066,  0.93561279],
#        [ 0.99898784, -1.62509   , -0.49851304, ...,  0.83688779,
#          0.48993682,  0.84032716],
#        [-1.32811466,  0.72807986, -0.42512381, ..., -0.0040537 ,
#          0.41140037,  0.36675999],
#        ...,
#        [ 1.0607357 , -0.48812373, -0.34254143, ...,  0.754531  ,
#          0.35304827,  0.24795779],
#        [-0.39048786,  0.8907987 , -0.33398802, ..., -0.27405781,
#          0.3405385 ,  0.53354324],
#        [-0.874829  ,  0.74302488, -0.44546643, ..., -0.34218657,
#          0.44383728,  0.70908793]])

# %%
adata.obsm[embeddings_key].shape
# Out:
# (10199, 10)

# %% [markdown]
# #### Initial Attempts at Understanding the 10-Dimensional Manifold Through PCA

# %%
from sklearn.decomposition import PCA

Z = adata.obsm[embeddings_key]   # shape (n_cells, 10)

max_k = Z.shape[1]   # = 10
recon_errors = []
var_explained = []

for k in range(1, max_k + 1):
    pca = PCA(n_components=k)
    Z_k = pca.fit_transform(Z)
    Z_recon = pca.inverse_transform(Z_k)

    # Mean squared reconstruction error
    mse = np.mean((Z - Z_recon) ** 2)
    recon_errors.append(mse)

    var_explained.append(np.sum(pca.explained_variance_ratio_))

# %%
elbow_df = pd.DataFrame({
    "n_components": np.arange(1, max_k + 1),
    "reconstruction_MSE": recon_errors,
    "cumulative_variance": var_explained
})

# %%
plt.plot(elbow_df["n_components"], elbow_df["reconstruction_MSE"], marker="o")
plt.xlabel("Number of PCA components")
plt.ylabel("Reconstruction MSE")
plt.title("PCA Elbow on 10-D latent space")
plt.show()

# %%
from kneed import KneeLocator

kneedle = KneeLocator(
    elbow_df["n_components"],
    elbow_df["reconstruction_MSE"],
    curve="convex",
    direction="decreasing"
)

optimal_k = kneedle.elbow
optimal_k
# Out:
# 4

# %% [markdown]
# #### Choose the `n_components` for PCA

# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA

Z = adata.obsm[embeddings_key]   # shape (n_cells, 10)

# Run PCA
pca = PCA(n_components=optimal_k)
Z_pca = pca.fit_transform(Z)

# Store PCs back in AnnData
adata.obsm["X_e10_pca"] = Z_pca

# Variance explained
var_exp = pca.explained_variance_ratio_
cum_var = np.cumsum(var_exp)

pd.DataFrame({
    "PC": [f"PC{i+1}" for i in range(optimal_k)],
    "Variance_explained": var_exp,
    "Cumulative": cum_var
})
# Out:
#     PC  Variance_explained  Cumulative
# 0  PC1            0.371109    0.371109
# 1  PC2            0.195222    0.566332
# 2  PC3            0.141649    0.707980
# 3  PC4            0.079461    0.787442

# %%
adata.obs["latent_PC1"] = Z_pca[:,0]
adata.obs["latent_PC2"] = Z_pca[:,1]
adata.obs["latent_PC3"] = Z_pca[:,2]
adata.obs["latent_PC4"] = Z_pca[:,3]

# %%
embeddings_key = "component4_e10"
desired_obs = 'latent_PC1'

visualize_embedding(
    embedding=adata.obsm[embeddings_key],
    obs_values=adata.obs[desired_obs],
    cat_colors=cat_colors,   # <--- pass the fixed mapping
    point_size=8,
    alpha=0.9,
    figsize=(7,7),
    show_legend=False
)

# %%
embeddings_key = "component4_e10"
desired_obs = 'latent_PC2'

visualize_embedding(
    embedding=adata.obsm[embeddings_key],
    obs_values=adata.obs[desired_obs],
    cat_colors=cat_colors,   # <--- pass the fixed mapping
    point_size=8,
    alpha=0.9,
    figsize=(7,7),
    show_legend=False
)

# %%
embeddings_key = "component4_e10"
desired_obs = 'latent_PC3'

visualize_embedding(
    embedding=adata.obsm[embeddings_key],
    obs_values=adata.obs[desired_obs],
    cat_colors=cat_colors,   # <--- pass the fixed mapping
    point_size=8,
    alpha=0.9,
    figsize=(7,7),
    show_legend=False
)

# %%
embeddings_key = "component4_e10"
desired_obs = 'latent_PC4'

visualize_embedding(
    embedding=adata.obsm[embeddings_key],
    obs_values=adata.obs[desired_obs],
    cat_colors=cat_colors,   # <--- pass the fixed mapping
    point_size=8,
    alpha=0.9,
    figsize=(7,7),
    show_legend=False
)

# %%
sc.pl.violin(
    adata,
    keys=["latent_PC1", "latent_PC2", "latent_PC3", "latent_PC4"],
    groupby="cell_type",   # or whatever your annotation is called
    rotation=90
)

# %%
from scipy.stats import spearmanr

X = adata.X.A if hasattr(adata.X, "A") else adata.X

pc_gene_corr = {}

for k, pc in enumerate(["latent_PC1", "latent_PC2", "latent_PC3", "latent_PC4"], start=1):
    scores = adata.obs[pc].values
    corrs = np.zeros(X.shape[1])

    for g in range(X.shape[1]):
        gene = X[:, g]

        # skip genes with no variance
        if np.std(gene) == 0:
            corrs[g] = 0.0
        else:
            corrs[g], _ = spearmanr(gene, scores)

    pc_gene_corr[f"PC{k}"] = corrs

# %%
ranked_genes = {}

for k in ["PC1", "PC2", "PC3", "PC4"]:
    r = pc_gene_corr[k]
    order = np.argsort(-r)
    ranked_genes[k] = pd.Series(r[order], index=adata.var_names[order])

# %%
ranked_genes["PC1"].isna().sum()
# Out:
# 0

# %%
ranked_genes['PC1']
# Out:
# MDK         0.564113
# IGFBP2      0.518490
# CALD1       0.516584
# COL18A1     0.511463
# KCNQ1OT1    0.509371
#               ...
# LTB        -0.421707
# CYTIP      -0.429897
# CD48       -0.435374
# PTPRC      -0.442154
# CD52       -0.504591
# Length: 31815, dtype: float64

# %%
# Question: Why do I have NAN values in some of my ranked genes' spearman correlations?

# %%
top_genes = {}

for pc in ["PC1", "PC2", "PC3"]:
    s = ranked_genes[pc]

    top_pos = s.head(10)        # most positively correlated
    top_neg = s.tail(10)        # most negatively correlated

    top_genes[pc] = {
        "positive": top_pos,
        "negative": top_neg
    }

    print(f"\n==== {pc} ====")
    print("Top positive:")
    print(top_pos)
    print("\nTop negative:")
    print(top_neg[::-1])
# Out:
# ==== PC1 ====
# Top positive:
# MDK         0.564113
# IGFBP2      0.518490
# CALD1       0.516584
# COL18A1     0.511463
# KCNQ1OT1    0.509371
# S100A13     0.504104
# MT-ND1      0.502937
# MT-ND4      0.499130
# SERPINH1    0.492891
# IFITM3      0.488972
# dtype: float64
#
# Top negative:
# CD52    -0.504591
# PTPRC   -0.442154
# CD48    -0.435374
# CYTIP   -0.429897
# LTB     -0.421707
# CD3D    -0.418690
# CD2     -0.417434
# CXCR4   -0.412702
# CD37    -0.407082
# TRAC    -0.398100
# dtype: float64
#
# ==== PC2 ====
# Top positive:
# SRGN      0.783539
# PTPRC     0.721086
# LAPTM5    0.716211
# TYROBP    0.704548
# ITGB2     0.693470
# FCER1G    0.682349
# FYB1      0.670839
# CD53      0.649265
# LYZ       0.641194
# FCGR3A    0.636368
# dtype: float64
#
# Top negative:
# KRT18     -0.718236
# WFDC2     -0.708679
# KRT19     -0.704250
# KRT8      -0.703419
# EPCAM     -0.676683
# CLDN3     -0.664325
# SLPI      -0.652648
# S100A13   -0.650651
# CD24      -0.642513
# KRT7      -0.631099
# dtype: float64
#
# ==== PC3 ====
# Top positive:
# CD2      0.621257
# CD3D     0.588787
# CD3E     0.574527
# CD3G     0.564356
# TRAC     0.546988
# TRBC2    0.524033
# GZMA     0.515379
# LCK      0.482830
# CD52     0.462100
# GZMM     0.458419
# dtype: float64
#
# Top negative:
# MARCKS   -0.648199
# LGALS1   -0.621585
# TIMP2    -0.618941
# CD63     -0.615109
# FTL      -0.607974
# CST3     -0.602351
# DAB2     -0.584841
# LRP1     -0.578777
# FN1      -0.577704
# PSAP     -0.570391
# dtype: float64

# %% [markdown]
# **Note**
# - Descriptions given for the genes below are not comprehensive and are summaries of information found on GeneCards
#
# ```
# ==== PC2 ====
# Top positive:
# SRGN      0.783539 - Formation of mast cell secretory granules. Storage of proteases in connective tissue, musosal mast cells and storage of granzyme B in T-lymphocytes. Localizes neutrophil elastase in azurophil granules of neutrophils.
# PTPRC     0.721086 - Cell growth, differentiation, mitosis, and oncogenic transformation. Regular of T- and B-cell antigen receptor signaling.
# LAPTM5    0.716211 - Encodes transmembrane receptor associated with lysosomes
# TYROBP    0.704548 - Encodes transmembrane signaling polypeptide which contains immunoreceptor tyrosine-based activation motif (ITAM). May be associated with killer-cell inhibitory receptor (KIR) family of membrane glycoproteins. Putative receptor, "triggering receptor expressed on myeloid cells 2"
# ITGB2     0.693470 - Encodes integrin beta chain to form integrin heterodimers. Participates in cell adhesion and cell-surface mediated signalling. Plays important role in immune response.
# FCER1G    0.682349 - Mediates allergic inflammatory signaling in mast cells
# FYB1      0.670839 - Encodes protein that serves as an adapter for FYN protein and LCP2 signaling cascades in T-cells. Encoded protein involved in platlet activation and controls expression of interleukin-2.
# CD53      0.649265 - Encodes protein that is member of transmembrane 4 superfamily. Most members cell surface proteins that mediate signal tr4ansduction and play role in cell development activation, growth, and motility. Encoded protein is cell surface glycoprotein that is known to complex with integrins. Contributes to transduction of CD2-generated signals in T cells and nature killer cells and been suggested to play role in growth regulation.
# LYZ       0.641194 - Encodes lysozyme (has antibacterial activity against a number of bacterial species)
# FCGR3A    0.636368 - Encodes receptor for Fc portion of immunoglobulin G, responsible for removal of antigen-antibody complexes from circulation
# dtype: float64
#
# Top negative:
# KRT18     -0.718236 - Encodes type I intermediate filament chain keratin 18
# WFDC2     -0.708679 - Encodes protein that is member of WFDC domain family. WFDC domain functions as a protease inhibitor in many family members. Expressed in pulmonary epithelial cells and found to be expressed in **some ovarian cancers** (What kind of ovarian cancers)?
# KRT19     -0.704250 - Ecnodes protein that is member of keratin family (keratins are intermediate filament proteins responsible for structural integrity of epithelial cells).
# KRT8      -0.703419 - Member of type II keratin family. Type i and type II keratins heteropolymerize to form intermediate-sized filaments in cytoplasm of epithelial cells. Proteins plays role in maintaining cellcular structural integrity and functions in signal transduction and cellcular differentiation.
# EPCAM     -0.676683 - Carcinoma-associated antigen. Expressed on most normal epithelial cells and gastrointestinal carcinomas?
# CLDN3     -0.664325 - Represent one mode of cell-to-cell adhesion in epithelial or endothelial cell sheets forming continuous seals around cells and serving as a physical barrier to prevent solutes and water from passing freely through the paracellular space. Encoded protein is an integral membrane protein.
# SLPI      -0.652648 - Encodes secreted inhibitor which protects epithelial tissues from serine proteases
# S100A13   -0.650651 - Encoded protein is member of S100 family of proteins containing 2 EF-hand calcium-binding motifs. Regulates cell cycle progression and differentiation. High expression in thyroid gland, smooth muscle cells.
# CD24      -0.642513 - Encodes sialoglycoprotein expressed on mature granulocytes and B cells.
# KRT7      -0.631099 - Encoded protein is member of kertain gene famil. Specifically expressed in simple epithelia lining cavities of internal organs and in gland ducts and blood vessels.
# dtype: float64
# ```

# %%
gene = "ITGB1"
gene_idx = adata.var_names.get_loc(gene)
expr = adata.X[:, gene_idx]

# %%
plt.hist(expr.todense(), bins=50)
plt.xlabel(f"{gene} expression")
plt.ylabel("Number of cells")
plt.title(f"Distribution of {gene}")
plt.show()

# %% [markdown]
# #### Pairwise Plots - 1 Sanity Check Against Sarah's Work

# %%
for cell_type in adata.obs["cell_type"].unique(): 
    print(cell_type)
# Out:
# T cell
# fallopian tube secretory epithelial cell
# fibroblast
# monocyte
# plasma cell
# dendritic cell
# endothelial cell
# B cell
# mast cell

# %%
mask_tcell = adata.obs["cell_type"] == "T cell"
mask_fallopian = adata.obs["cell_type"] == "fallopian tube secretory epithelial cell"
mask_fibroblast = adata.obs["cell_type"] == "fibroblast"
mask_monocyte = adata.obs["cell_type"] == "monocyte"
mask_plasma = adata.obs["cell_type"] == "plasma cell"
mask_dendritic = adata.obs["cell_type"] == "dendritic cell"
mask_endothelial = adata.obs["cell_type"] == "endothelial cell"
mask_bcell = adata.obs["cell_type"] == "B cell"
mask_mast = adata.obs["cell_type"] == "mast cell"

# %%
# T-cells
embeddings_key = "component2_e10"
desired_obs = 'interferon_score'

visualize_embedding(
    embedding=adata.obsm[embeddings_key][mask_tcell],
    obs_values=adata.obs[desired_obs][mask_tcell],
    cmap=plt.cm.viridis,
    c_bar_label=desired_obs,
    bbox_to_anchor=(1.23, 1.01),
    title = "T-Cells : Interferon Subspace" 
)

# %%
# Fallopian tube secretory epithelial cell
embeddings_key = "component2_e10"
desired_obs = 'interferon_score'

visualize_embedding(
    embedding=adata.obsm[embeddings_key][mask_fallopian],
    obs_values=adata.obs[desired_obs][mask_fallopian],
    cmap=plt.cm.viridis,
    c_bar_label=desired_obs,
    bbox_to_anchor=(1.23, 1.01),
    title = "Fallopian Tube Secretory Epithelial Cell : Interferon Subspace" 
)

# %%
# Fibroblast 
embeddings_key = "component2_e10"
desired_obs = 'interferon_score'

visualize_embedding(
    embedding=adata.obsm[embeddings_key][mask_fibroblast],
    obs_values=adata.obs[desired_obs][mask_fibroblast],
    cmap=plt.cm.viridis,
    c_bar_label=desired_obs,
    bbox_to_anchor=(1.23, 1.01),
    title = "Fibroblast : Interferon Subspace" 
)

# %%
# Monocyte
embeddings_key = "component2_e10"
desired_obs = 'interferon_score'

visualize_embedding(
    embedding=adata.obsm[embeddings_key][mask_monocyte],
    obs_values=adata.obs[desired_obs][mask_monocyte],
    cmap=plt.cm.viridis,
    c_bar_label=desired_obs,
    bbox_to_anchor=(1.23, 1.01),
    title = "Monocyte : Interferon Subspace" 
)

# %%
# Plasma cell
embeddings_key = "component2_e10"
desired_obs = 'interferon_score'

visualize_embedding(
    embedding=adata.obsm[embeddings_key][mask_plasma],
    obs_values=adata.obs[desired_obs][mask_plasma],
    cmap=plt.cm.viridis,
    c_bar_label=desired_obs,
    bbox_to_anchor=(1.23, 1.01),
    title = "Plasma Cell : Interferon Subspace" 
)

# %%
# Dendritic cell
embeddings_key = "component2_e10"
desired_obs = 'interferon_score'

visualize_embedding(
    embedding=adata.obsm[embeddings_key][mask_dendritic],
    obs_values=adata.obs[desired_obs][mask_dendritic],
    cmap=plt.cm.viridis,
    c_bar_label=desired_obs,
    bbox_to_anchor=(1.23, 1.01),
    title = "Dendritic Cell : Interferon Subspace" 
)

# %%
# Endothelial cell
embeddings_key = "component2_e10"
desired_obs = 'interferon_score'

visualize_embedding(
    embedding=adata.obsm[embeddings_key][mask_endothelial],
    obs_values=adata.obs[desired_obs][mask_endothelial],
    cmap=plt.cm.viridis,
    c_bar_label=desired_obs,
    bbox_to_anchor=(1.23, 1.01),
    title = "Endothelial Cell : Interferon Subspace" 
)

# %%
# B cell
embeddings_key = "component2_e10"
desired_obs = 'interferon_score'

visualize_embedding(
    embedding=adata.obsm[embeddings_key][mask_bcell],
    obs_values=adata.obs[desired_obs][mask_bcell],
    cmap=plt.cm.viridis,
    c_bar_label=desired_obs,
    bbox_to_anchor=(1.23, 1.01),
    title = "B Cell : Interferon Subspace" 
)

# %%
# mast cell
embeddings_key = "component2_e10"
desired_obs = 'interferon_score'

visualize_embedding(
    embedding=adata.obsm[embeddings_key][mask_mast],
    obs_values=adata.obs[desired_obs][mask_mast],
    cmap=plt.cm.viridis,
    c_bar_label=desired_obs,
    bbox_to_anchor=(1.23, 1.01),
    title = "mast cell : Interferon Subspace" 
)

# %% [markdown]
# #### Pairwise Plots - 2 Dissociation Experiments

# %%
# T-cells
embeddings_key = "component3_e10"
desired_obs = 'dissociation_score'

visualize_embedding(
    embedding=adata.obsm[embeddings_key][mask_tcell],
    obs_values=adata.obs[desired_obs][mask_tcell],
    cmap=plt.cm.viridis,
    c_bar_label=desired_obs,
    bbox_to_anchor=(1.23, 1.01),
    title = "T-Cells : Dissociation Subspace" 
)

# %%
# Fallopian tube secretory epithelial cell
embeddings_key = "component3_e10"
desired_obs = 'dissociation_score'

visualize_embedding(
    embedding=adata.obsm[embeddings_key][mask_fallopian],
    obs_values=adata.obs[desired_obs][mask_fallopian],
    cmap=plt.cm.viridis,
    c_bar_label=desired_obs,
    bbox_to_anchor=(1.23, 1.01),
    title = "Fallopian Tube Secretory Epithelial Cell : Dissociation Subspace" 
)

# %%
# Fibroblast 
embeddings_key = "component3_e10"
desired_obs = 'dissociation_score'
visualize_embedding(
    embedding=adata.obsm[embeddings_key][mask_fibroblast],
    obs_values=adata.obs[desired_obs][mask_fibroblast],
    cmap=plt.cm.viridis,
    c_bar_label=desired_obs,
    bbox_to_anchor=(1.23, 1.01),
    title = "Fibroblast : Dissociation Subspace" 
)

# %%
# Monocyte
embeddings_key = "component3_e10"
desired_obs = 'interferon_score'

visualize_embedding(
    embedding=adata.obsm[embeddings_key][mask_monocyte],
    obs_values=adata.obs[desired_obs][mask_monocyte],
    cmap=plt.cm.viridis,
    c_bar_label=desired_obs,
    bbox_to_anchor=(1.23, 1.01),
    title = "Monocyte : Dissociation Subspace" 
)

# %%
# Plasma cell
embeddings_key = "component3_e10"
desired_obs = 'interferon_score'

visualize_embedding(
    embedding=adata.obsm[embeddings_key][mask_plasma],
    obs_values=adata.obs[desired_obs][mask_plasma],
    cmap=plt.cm.viridis,
    c_bar_label=desired_obs,
    bbox_to_anchor=(1.23, 1.01),
    title = "Plasma Cell : Dissociation Subspace" 
)

# %%
# Dendritic cell
embeddings_key = "component3_e10"
desired_obs = 'interferon_score'

visualize_embedding(
    embedding=adata.obsm[embeddings_key][mask_dendritic],
    obs_values=adata.obs[desired_obs][mask_dendritic],
    cmap=plt.cm.viridis,
    c_bar_label=desired_obs,
    bbox_to_anchor=(1.23, 1.01),
    title = "Dendritic Cell : Dissociation Subspace" 
)

# %%
# Endothelial cell
embeddings_key = "component3_e10"
desired_obs = 'interferon_score'

visualize_embedding(
    embedding=adata.obsm[embeddings_key][mask_endothelial],
    obs_values=adata.obs[desired_obs][mask_endothelial],
    cmap=plt.cm.viridis,
    c_bar_label=desired_obs,
    bbox_to_anchor=(1.23, 1.01),
    title = "Endothelial Cell : Dissociation Subspace" 
)

# %%
# B cell
embeddings_key = "component3_e10"
desired_obs = 'interferon_score'

visualize_embedding(
    embedding=adata.obsm[embeddings_key][mask_bcell],
    obs_values=adata.obs[desired_obs][mask_bcell],
    cmap=plt.cm.viridis,
    c_bar_label=desired_obs,
    bbox_to_anchor=(1.23, 1.01),
    title = "B Cell : Dissociation Subspace" 
)

# %%
# mast cell
embeddings_key = "component3_e10"
desired_obs = 'interferon_score'

visualize_embedding(
    embedding=adata.obsm[embeddings_key][mask_mast],
    obs_values=adata.obs[desired_obs][mask_mast],
    cmap=plt.cm.viridis,
    c_bar_label=desired_obs,
    bbox_to_anchor=(1.23, 1.01),
    title = "mast cell : Dissocation Subspace" 
)

# %%
adata.obs["cell_type"].unique()
# Out:
# cell_id
# SPECTRUM-OV-070_S1_CD45P_ASCITES_CCGGTGAGTATGGAGC                                                   T cell
# SPECTRUM-OV-037_S1_CD45N_LEFT_OVARY_GGGATCCTCATGCGGC              fallopian tube secretory epithelial cell
# SPECTRUM-OV-054_S1_CD45P_INFRACOLIC_OMENTUM_TTGAACGTCCGCATAA                                        T cell
# SPECTRUM-OV-041_S1_CD45N_RIGHT_FALLOPIAN_TUBE_TGTAAGCCACATACTG                                  fibroblast
# SPECTRUM-OV-031_S1_CD45P_LEFT_FALLOPIAN_TUBE_CTCAAGAAGCACACAG                                       T cell
#                                                                                     ...
# SPECTRUM-OV-041_S1_CD45P_RIGHT_FALLOPIAN_TUBE_CTTGATTAGGCAGTCA                                      T cell
# SPECTRUM-OV-054_S1_CD45N_INFRACOLIC_OMENTUM_CAGGGCTAGAGCCGAT                                    fibroblast
# SPECTRUM-OV-082_S1_CD45N_BOWEL_GTCTTTAAGAAACTAC                   fallopian tube secretory epithelial cell
# SPECTRUM-OV-009_S1_CD45P_RIGHT_OVARY_TCACTCGCATCTCGTC                                               T cell
# SPECTRUM-OV-071_S1_CD45P_LEFT_OVARY_AGGCATTTCCGACAGC                                                T cell
# Name: cell_type, Length: 10199, dtype: category
# Categories (9, object): ['fibroblast', 'T cell', 'mast cell', 'endothelial cell', ..., 'dendritic cell', 'plasma cell', 'fallopian tube secretory epithelial cell', 'monocyte']

# %%
adata.obsm[embeddings_key]
# Out:
# array([[-0.16527286,  0.23965319,  0.59899458, ...,  0.45320239,
#         -0.52260051, -0.23355896],
#        [-0.16527286,  0.23965319,  0.59899458, ...,  0.45320239,
#         -0.52260051, -0.23355896],
#        [-0.16527286,  0.23965319,  0.59899458, ...,  0.45320239,
#         -0.52260051, -0.23355896],
#        ...,
#        [-0.16527286,  0.23965319,  0.59899458, ...,  0.45320239,
#         -0.52260051, -0.23355896],
#        [-0.16527286,  0.23965319,  0.59899458, ...,  0.45320239,
#         -0.52260051, -0.23355896],
#        [-0.16527286,  0.23965319,  0.59899458, ...,  0.45320239,
#         -0.52260051, -0.23355896]], shape=(10199, 10))

# %%
adata.obs[desired_obs]
# Out:
# cell_id
# SPECTRUM-OV-070_S1_CD45P_ASCITES_CCGGTGAGTATGGAGC                -0.066753
# SPECTRUM-OV-037_S1_CD45N_LEFT_OVARY_GGGATCCTCATGCGGC             -0.060493
# SPECTRUM-OV-054_S1_CD45P_INFRACOLIC_OMENTUM_TTGAACGTCCGCATAA     -0.054439
# SPECTRUM-OV-041_S1_CD45N_RIGHT_FALLOPIAN_TUBE_TGTAAGCCACATACTG   -0.080584
# SPECTRUM-OV-031_S1_CD45P_LEFT_FALLOPIAN_TUBE_CTCAAGAAGCACACAG    -0.061362
#                                                                     ...
# SPECTRUM-OV-041_S1_CD45P_RIGHT_FALLOPIAN_TUBE_CTTGATTAGGCAGTCA    0.003020
# SPECTRUM-OV-054_S1_CD45N_INFRACOLIC_OMENTUM_CAGGGCTAGAGCCGAT     -0.224252
# SPECTRUM-OV-082_S1_CD45N_BOWEL_GTCTTTAAGAAACTAC                  -0.173922
# SPECTRUM-OV-009_S1_CD45P_RIGHT_OVARY_TCACTCGCATCTCGTC            -0.052288
# SPECTRUM-OV-071_S1_CD45P_LEFT_OVARY_AGGCATTTCCGACAGC              0.029909
# Name: G2M.Score, Length: 10199, dtype: float32

# %% [markdown]
# **QUESTIONS**
# - Is using "everything else" to capture cell type really the best technique to use?
# - Why does CellUntangler use the first latent subspace to reconstruct the genes that don't belong in the gene mask (when only the first latent subspace is used for reconstructing those genes that belong in the first gene mask)?
#   A decision I need to might need to make (if the code doesn't already think about this and implement it)
#   - Should all earlier subspaces contribute to the reconstruction of subsets of genes corresponding to later subspaces? Or, should only the last subset of genes (presumably corresponding to the largest number of genes) be reconstructed using the all latent subspaces up to the last subspace?
#   - A sub-question: what guarantees disentanglement in models like CellUntangler?
#   - Hmmm, if we stopped the gradient for all earlier subspaces when training later subspaces, would this ensure that earlier subspaces never "tweak" their parameters to get better at reconstructing a subset of genes unrelated to the subset of genes they should best reconstruct?
#
# What owu

# %% [markdown]
# **Worklist**
# - (HSSOC) Getting stuck on 2+ subspace CellUntangler (Get blocked on nuances of stopping gradients)
# - (Liver) Getting stuck on better benchmarking
# - (Liver) Getting started on biological analysis of different dimensions + generating pairwise plots of disentangled dimensions

# %% [markdown]
# **Ideas**
# - Might be useful to mix HGSOC dataset with non-cancerous cells to see how well the cell dissociation signal is captured in a particular latent space

# %% [markdown]
# **Deep Dives**
# - What makes a "rotated" hyperbolic component "rotated"?
# - How to visualize learnable curvatures in latent spaces?
